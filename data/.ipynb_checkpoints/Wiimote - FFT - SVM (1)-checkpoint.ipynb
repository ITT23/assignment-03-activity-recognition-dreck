# %% [markdown]
# # Using the Fast Fourier Transform and Support Vector Machines to classify activity data

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams.update({'figure.figsize': (12.0, 8.0)})

# %%
from pylab import *
from scipy.fft import fft
from sklearn import svm
import numpy as np

# %% [markdown]
# ## We have logged some sensor data for three different activities - let's see whether we can use it to classify activities

# %%
# remove the trailing empty line from all csv files before importing them!
# you can also get the list of files via `glob.glob("./stand_*.csv")`
stand_csv = ["./standing1.csv", "./standing2.csv", "./stannding3.csv", "./standing4.csv", "./standing5.csv"]
walk_csv = ["./walking1.csv", "./walking2.csv", "./walking3.csv", "./walking4.csv"]
punch_csv = ["./punching1.csv", "./punching2.csv", "./punching3.csv", "./punching4.csv"]

# %%
# in practice, you would do this with csv.Reader or pandas
def read_data(filename):
    x = []
    y = []
    z = []
    avg = []
    for line in open(filename, "r").readlines():
        _x, _y, _z = map(int,line.strip().split(","))
        x.append(_x)
        y.append(_y)
        z.append(_z)
        avg.append((_x+_y+_z)/3)
    return avg

# %%
stand_raw = [read_data(f) for f in stand_csv]
walk_raw  = [read_data(f) for f in walk_csv]
hop_raw  = [read_data(f) for f in hop_csv]

stand_raw
# Out:
# [[541.3333333333334,
#   551.0,
#   549.6666666666666,
#   547.6666666666666,
#   545.6666666666666,
#   547.0,
#   547.0,
#   546.6666666666666,
#   547.0,
#   546.6666666666666,
#   546.6666666666666,
#   547.0,
#   546.6666666666666,
#   546.3333333333334,
#   547.0,
#   547.0,
#   547.0,
#   547.0,
#   547.0,
#   546.6666666666666,
#   547.6666666666666,
#   547.3333333333334,
#   547.0,
#   547.3333333333334,
#   548.0,
#   547.6666666666666,
#   548.0,
#   547.3333333333334,
#   548.0,
#   546.6666666666666,
#   547.3333333333334,
#   546.3333333333334,
#   547.3333333333334,
#   547.0,
#   547.6666666666666,
#   547.6666666666666,
#   547.0,
#   546.6666666666666,
#   548.0,
#   547.0,
#   546.3333333333334,
#   547.3333333333334,
#   547.6666666666666,
#   546.6666666666666,
#   547.6666666666666,
#   547.6666666666666,
#   547.3333333333334,
#   548.0,
#   547.3333333333334,
#   548.0,
#   547.6666666666666,
#   548.0,
#   547.6666666666666,
#   548.0,
#   547.6666666666666,
#   546.3333333333334,
#   547.6666666666666,
#   547.3333333333334,
#   546.6666666666666,
#   547.3333333333334,
#   548.3333333333334,
#   547.3333333333334,
#   548.0,
#   547.6666666666666,
#   547.0,
#   547.3333333333334,
#   547.6666666666666,
#   548.0,
#   548.3333333333334,
#   547.0,
#   547.6666666666666,
#   547.6666666666666,
#   548.0,
#   547.3333333333334,
#   548.3333333333334,
#   547.3333333333334,
#   548.0,
#   547.3333333333334,
#   548.0,
#   548.6666666666666,
#   548.0,
#   548.3333333333334,
#   549.3333333333334,
#   548.3333333333334,
#   547.3333333333334,
#   548.6666666666666,
#   550.0],
#  [543.3333333333334,
#   544.6666666666666,
#   544.0,
#   545.3333333333334,
#   545.3333333333334,
#   545.0,
#   546.6666666666666,
#   547.6666666666666,
#   548.3333333333334,
#   549.0,
#   550.3333333333334,
#   547.0,
#   545.6666666666666,
#   545.6666666666666,
#   547.0,
#   546.0,
#   546.3333333333334,
#   547.3333333333334,
#   547.6666666666666,
#   545.3333333333334,
#   546.0,
#   547.0,
#   546.3333333333334,
#   546.6666666666666,
#   546.0,
#   545.6666666666666,
#   546.0,
#   547.0,
#   547.3333333333334,
#   546.6666666666666,
#   546.0,
#   546.3333333333334,
#   546.0,
#   546.0,
#   546.3333333333334,
#   547.0,
#   546.6666666666666,
#   547.6666666666666,
#   547.6666666666666,
#   548.0,
#   547.6666666666666,
#   548.3333333333334,
#   548.6666666666666,
#   548.3333333333334,
#   548.0,
#   548.3333333333334,
#   546.0,
#   546.6666666666666,
#   547.6666666666666,
#   548.0,
#   548.3333333333334,
#   549.3333333333334,
#   548.0,
#   548.0,
#   549.0,
#   549.6666666666666,
#   549.0,
#   548.3333333333334,
#   547.6666666666666,
#   547.3333333333334,
#   548.3333333333334,
#   548.0,
#   547.0,
#   548.6666666666666,
#   549.3333333333334,
#   549.3333333333334,
#   547.0,
#   549.0,
#   549.3333333333334,
#   548.6666666666666,
#   549.0,
#   548.3333333333334,
#   547.0,
#   551.3333333333334]]

# %%
# cut off 
all = stand_raw + walk_raw + hop_raw
minlen = min([len(x) for x in all])
print("Cutting off after", minlen , "samples")
stand_cut = [l[:minlen] for l in stand_raw]
walk_cut = [l[:minlen] for l in walk_raw]
hop_cut = [l[:minlen] for l in hop_raw]

stand_cut
# Out:
# Cutting off after 58 samples
# [[541.3333333333334,
#   551.0,
#   549.6666666666666,
#   547.6666666666666,
#   545.6666666666666,
#   547.0,
#   547.0,
#   546.6666666666666,
#   547.0,
#   546.6666666666666,
#   546.6666666666666,
#   547.0,
#   546.6666666666666,
#   546.3333333333334,
#   547.0,
#   547.0,
#   547.0,
#   547.0,
#   547.0,
#   546.6666666666666,
#   547.6666666666666,
#   547.3333333333334,
#   547.0,
#   547.3333333333334,
#   548.0,
#   547.6666666666666,
#   548.0,
#   547.3333333333334,
#   548.0,
#   546.6666666666666,
#   547.3333333333334,
#   546.3333333333334,
#   547.3333333333334,
#   547.0,
#   547.6666666666666,
#   547.6666666666666,
#   547.0,
#   546.6666666666666,
#   548.0,
#   547.0,
#   546.3333333333334,
#   547.3333333333334,
#   547.6666666666666,
#   546.6666666666666,
#   547.6666666666666,
#   547.6666666666666,
#   547.3333333333334,
#   548.0,
#   547.3333333333334,
#   548.0,
#   547.6666666666666,
#   548.0,
#   547.6666666666666,
#   548.0,
#   547.6666666666666,
#   546.3333333333334,
#   547.6666666666666,
#   547.3333333333334],
#  [543.3333333333334,
#   544.6666666666666,
#   544.0,
#   545.3333333333334,
#   545.3333333333334,
#   545.0,
#   546.6666666666666,
#   547.6666666666666,
#   548.3333333333334,
#   549.0,
#   550.3333333333334,
#   547.0,
#   545.6666666666666,
#   545.6666666666666,
#   547.0,
#   546.6666666666666,
#   545.6666666666666,
#   546.3333333333334,
#   546.0,
#   546.6666666666666,
#   547.0,
#   546.0,
#   545.3333333333334,
#   545.6666666666666,
#   545.6666666666666,
#   546.0,
#   545.3333333333334,
#   546.0,
#   546.0,
#   545.3333333333334,
#   545.0,
#   546.0,
#   545.6666666666666,
#   548.0,
#   548.0,
#   548.3333333333334,
#   548.6666666666666,
#   547.6666666666666,
#   547.3333333333334,
#
# [541.3333333333334, 551.0, 549.6666666666666, 547.6666666666666, 545.6666666666666, 547.0, 547.0, 546.6666666666666, 547.0, 546.6666666666666, 546.6666666666666, 547.0, 546.6666666666666, 546.3333333333334, 547.0, 547.0, 547.0, 547.0, 547.0, 546.6666666666666, 547.6666666666666, 547.3333333333334, 547.0, 547.3333333333334, 548.0, 547.6666666666666, 548.0, 547.3333333333334, 548.0, 546.6666666666666, 547.3333333333334, 546.3333333333334, 547.3333333333334, 547.0, 547.6666666666666, 547.6666666666666, 547.0, 546.6666666666666, 548.0, 547.0, 546.3333333333334, 547.3333333333334, 547.6666666666666, 546.6666666666666, 547.6666666666666, 547.6666666666666, 547.3333333333334, 548.0, 547.3333333333334, 548.0, 547.6666666666666, 548.0, 547.6666666666666, 548.0, 547.6666666666666, 546.3333333333334, 547.6666666666666, 547.3333333333334]

# %% [markdown]
# ## Naive implementation: just throw data at the classifier

# %%
c = svm.SVC()

# %%
# we will use the first example of each class as test data and the rest as training data
STAND = 0
WALK = 1
HOP = 2
categories = [STAND] * 3 + [WALK] * 3 + [HOP] * 3
training_data = stand_cut[1:] + walk_cut[1:] + hop_cut[1:]
c.fit(training_data,categories)
# Out:
# SVC()

# %%
c.predict([stand_cut[0], walk_cut[0], hop_cut[0]]) # should be [0, 1, 2]
# Out:
# array([0, 0, 2])

# %%
# we will use the first example of each class as test data and the rest as training data
STAND = 0
WALK = 1
HOP = 2
categories = [STAND] * 3 + [WALK] * 3 + [HOP] * 3
training_data = stand_cut[1:] + walk_cut[1:] + hop_cut[1:]
c.fit(training_data,categories)
# Out:
# SVC()

# %% [markdown]
# ## Let's try a neural network!

# %%
from sklearn.neural_network import MLPClassifier
mlc = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)

mlc.fit(training_data, categories)
mlc.predict([stand_cut[0], walk_cut[0], hop_cut[0]])
# Out:
# array([1, 1, 1])

# %% [markdown]
# General principle: "garbage in - garbage out".
#
# While sufficiently large neural networks may find patterns, you would need large training data sets.

# %% [markdown]
# ## Try No. 2: Let's help the classifier...

# %% [markdown]
# ### First step: take a look at the data

# %%
for example in stand_cut:
    plot(example, c='r')

# %%
for example in walk_cut:
    plot(example, c='g')

# %%
for example in hop_cut:
    plot(example, c='b')

# %%
plot(stand_cut[0], c='r')
plot(walk_cut[0], c='b')
plot(hop_cut[0], c='g')

# %% [markdown]
# ### Preprocessing Raw Data using the FFT

# %%
stand_freq = [np.abs(fft(l)/len(l))[1:len(l)//2] for l in stand_cut]
walk_freq = [np.abs(fft(l)/len(l))[1:len(l)//2] for l in walk_cut]
hop_freq = [np.abs(fft(l)/len(l))[1:len(l)//2] for l in hop_cut]

# %%
for x in range(4):
    plot(range(len(hop_freq[x])), hop_freq[x])

# %%
for x in range(4):
    plot(range(len(walk_freq[x])), walk_freq[x])

# %%
for x in range(4):
    plot(range(len(stand_freq[x])), stand_freq[x])

# %% [markdown]
# ### Train an SVM classifier

# %%
c = svm.SVC()

# %%
STAND = 0
WALK = 1
HOP = 2
categories = [STAND] * 3 + [WALK] * 3 + [HOP] * 3
training_data = stand_freq[1:] + walk_freq[1:] + hop_freq[1:]
c.fit(training_data,categories)
# Out:
# SVC()

# %%
c.predict([stand_freq[0], walk_freq[0], hop_freq[0]])
# Out:
# array([0, 1, 2])

# %% [markdown]
# ## Yay!

# %% [markdown]
# (Bonus question: why not just use the mean value of each example for classification)
